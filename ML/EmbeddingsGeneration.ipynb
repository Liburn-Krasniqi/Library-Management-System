# %%
import pandas as pd
import numpy as np

# %%
# View Config
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 1000)
pd.set_option('max_colwidth', 400)

# %%
df = pd.read_csv('goodreads_data.csv')

# %%
df.head(1)
# Out:
#    Unnamed: 0                   Book      Author                                                                                                                                                                                                                                                                                                                                                                                                      Description                                                                                              Genres  Avg_Rating Num_Ratings                                                             URL
# 0           0  To Kill a Mockingbird  Harper Lee  The unforgettable novel of a childhood in a sleepy Southern town and the crisis of conscience that rocked it. "To Kill A Mockingbird" became both an instant bestseller and a critical success when it was first published in 1960. It went on to win the Pulitzer Prize in 1961 and was later made into an Academy Award-winning film, also a classic.Compassionate, dramatic, and deeply moving, "To Kill ...  ['Classics', 'Fiction', 'Historical Fiction', 'School', 'Literature', 'Young Adult', 'Historical']        4.27   5,691,311  https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Book', 'Author', 'Description', 'Genres', 'Avg_Rating', 'Num_Ratings', 'URL'], dtype='object')

# %%
def create_textual_representation(row):
    return f"""Book: {row['Book']}
Author: {row['Author']}
Genres: {row['Genres']}
Description: {row['Description']}
"""

# %%
df['textual_representation'] = df.apply(create_textual_representation, axis=1)

# %%
df.head(1)
# Out:
#    Unnamed: 0                   Book      Author                                                                                                                                                                                                                                                                                                                                                                                                      Description                                                                                              Genres  Avg_Rating Num_Ratings                                                             URL  \
# 0           0  To Kill a Mockingbird  Harper Lee  The unforgettable novel of a childhood in a sleepy Southern town and the crisis of conscience that rocked it. "To Kill A Mockingbird" became both an instant bestseller and a critical success when it was first published in 1960. It went on to win the Pulitzer Prize in 1961 and was later made into an Academy Award-winning film, also a classic.Compassionate, dramatic, and deeply moving, "To Kill ...  ['Classics', 'Fiction', 'Historical Fiction', 'School', 'Literature', 'Young Adult', 'Historical']        4.27   5,691,311  https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird
#
#                                                                                                                                                                                                                                                                                                                                                                                             textual_representation
# 0  Book: To Kill a Mockingbird\nAuthor: Harper Lee\nGenres: ['Classics', 'Fiction', 'Historical Fiction', 'School', 'Literature', 'Young Adult', 'Historical']\nDescription: The unforgettable novel of a childhood in a sleepy Southern town and the crisis of conscience that rocked it. "To Kill A Mockingbird" became both an instant bestseller and a critical success when it was first published in 1960...

# %%
# !pip install "pymilvus[model]"
# Out:
# Requirement already satisfied: pymilvus[model] in /opt/anaconda3/lib/python3.12/site-packages (2.6.3)
# Requirement already satisfied: setuptools>69 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus[model]) (80.8.0)
# Requirement already satisfied: grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus[model]) (1.74.0)
# Requirement already satisfied: orjson>=3.10.15 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus[model]) (3.11.2)
# Requirement already satisfied: protobuf>=5.27.2 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus[model]) (6.32.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus[model]) (1.1.1)
# Requirement already satisfied: pandas>=1.2.4 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus[model]) (2.2.3)
# Requirement already satisfied: pymilvus.model>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus[model]) (0.3.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2.4->pymilvus[model]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2.4->pymilvus[model]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2.4->pymilvus[model]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2.4->pymilvus[model]) (2023.3)
# Requirement already satisfied: transformers>=4.36.0 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]) (4.52.3)
# Requirement already satisfied: onnxruntime in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]) (1.22.1)
# Requirement already satisfied: scipy>=1.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]) (1.13.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus[model]) (1.16.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.32.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2024.9.11)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (1.1.2)
# Requirement already satisfied: coloredlogs in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (25.2.10)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/anaconda3/lib/python3.12/site-packages (from coloredlogs->onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy->onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (1.3.0)

# %%
from pymilvus import model

embedding_fn = model.DefaultEmbeddingFunction()

# %%
docs = [i for i in df['textual_representation']]

# %%
import numpy as np
import faiss
dim = 768

index = faiss.IndexFlatL2(dim)

X = np.zeros((len(df['textual_representation']), dim), dtype='float32')

# %%
X.shape
# Out:
# (10000, 768)

# %%
for i, representation in enumerate(df['textual_representation']):
    embedding = embedding_fn.encode_documents([representation])

    X[i] = np.array(embedding)
        
    if i % 30 == 0:
        print('processed', str(i), 'instances')
# Out:
# processed 0 instances
# processed 30 instances
# processed 60 instances
# processed 90 instances
# processed 120 instances
# processed 150 instances
# processed 180 instances
# processed 210 instances
# processed 240 instances
# processed 270 instances
# processed 300 instances
# processed 330 instances
# processed 360 instances
# processed 390 instances
# processed 420 instances
# processed 450 instances
# processed 480 instances
# processed 510 instances
# processed 540 instances
# processed 570 instances
# processed 600 instances
# processed 630 instances
# processed 660 instances
# processed 690 instances
# processed 720 instances
# processed 750 instances
# processed 780 instances
# processed 810 instances
# processed 840 instances
# processed 870 instances
# processed 900 instances
# processed 930 instances
# processed 960 instances
# processed 990 instances
# processed 1020 instances
# processed 1050 instances
# processed 1080 instances
# processed 1110 instances
# processed 1140 instances
# processed 1170 instances
# processed 1200 instances
# processed 1230 instances
# processed 1260 instances
# processed 1290 instances
# processed 1320 instances
# processed 1350 instances
# processed 1380 instances
# processed 1410 instances
# processed 1440 instances
# processed 1470 instances
# processed 1500 instances
# processed 1530 instances
# processed 1560 instances
# processed 1590 instances
# processed 1620 instances
# processed 1650 instances
# processed 1680 instances
# processed 1710 instances
# processed 1740 instances
# processed 1770 instances
# processed 1800 instances
# processed 1830 instances
# processed 1860 instances
# processed 1890 instances
# processed 1920 instances
# processed 1950 instances
# processed 1980 instances
# processed 2010 instances
# processed 2040 instances
# processed 2070 instances
# processed 2100 instances
# processed 2130 instances
# processed 2160 instances
# processed 2190 instances
# processed 2220 instances
# processed 2250 instances
# processed 2280 instances
# processed 2310 instances
# processed 2340 instances
# processed 2370 instances
# processed 2400 instances
# processed 2430 instances
# processed 2460 instances
# processed 2490 instances
# processed 2520 instances
# processed 2550 instances
# processed 2580 instances
# processed 2610 instances
# processed 2640 instances
# processed 2670 instances
# processed 2700 instances
# processed 2730 instances
# processed 2760 instances
# processed 2790 instances
# processed 2820 instances
# processed 2850 instances
# processed 2880 instances
# processed 2910 instances
# processed 2940 instances
# processed 2970 instances
# processed 3000 instances
# processed 3030 instances
# processed 3060 instances
# processed 3090 instances
# processed 3120 instances
# processed 3150 instances
# processed 3180 instances
# processed 3210 instances
# processed 3240 instances
# processed 3270 instances
# processed 3300 instances
# processed 3330 instances
# processed 3360 instances
# processed 3390 instances
# processed 3420 instances
# processed 3450 instances
# processed 3480 instances
# processed 3510 instances
# processed 3540 instances
# processed 3570 instances
# processed 3600 instances
# processed 3630 instances
# processed 3660 instances
# processed 3690 instances
# processed 3720 instances
# processed 3750 instances
# processed 3780 instances
# processed 3810 instances
# processed 3840 instances
# processed 3870 instances
# processed 3900 instances
# processed 3930 instances
# processed 3960 instances
# processed 3990 instances
# processed 4020 instances
# processed 4050 instances
# processed 4080 instances
# processed 4110 instances
# processed 4140 instances
# processed 4170 instances
# processed 4200 instances
# processed 4230 instances
# processed 4260 instances
# processed 4290 instances
# processed 4320 instances
# processed 4350 instances
# processed 4380 instances
# processed 4410 instances
# processed 4440 instances
# processed 4470 instances
# processed 4500 instances
# processed 4530 instances
# processed 4560 instances
# processed 4590 instances
# processed 4620 instances
# processed 4650 instances
# processed 4680 instances
# processed 4710 instances
# processed 4740 instances
# processed 4770 instances
# processed 4800 instances
# processed 4830 instances
# processed 4860 instances
# processed 4890 instances
# processed 4920 instances
# processed 4950 instances
# processed 4980 instances
# processed 5010 instances
# processed 5040 instances
# processed 5070 instances
# processed 5100 instances
# processed 5130 instances
# processed 5160 instances
# processed 5190 instances
# processed 5220 instances
# processed 5250 instances
# processed 5280 instances
# processed 5310 instances
# processed 5340 instances
# processed 5370 instances
# processed 5400 instances
# processed 5430 instances
# processed 5460 instances
# processed 5490 instances
# processed 5520 instances
# processed 5550 instances
# processed 5580 instances
# processed 5610 instances
# processed 5640 instances
# processed 5670 instances
# processed 5700 instances
# processed 5730 instances
# processed 5760 instances
# processed 5790 instances
# processed 5820 instances
# processed 5850 instances
# processed 5880 instances
# processed 5910 instances
# processed 5940 instances
# processed 5970 instances
# processed 6000 instances
# processed 6030 instances
# processed 6060 instances
# processed 6090 instances
# processed 6120 instances
# processed 6150 instances
# processed 6180 instances
# processed 6210 instances
# processed 6240 instances
# processed 6270 instances
# processed 6300 instances
# processed 6330 instances
# processed 6360 instances
# processed 6390 instances
# processed 6420 instances
# processed 6450 instances
# processed 6480 instances
# processed 6510 instances
# processed 6540 instances
# processed 6570 instances
# processed 6600 instances
# processed 6630 instances
# processed 6660 instances
# processed 6690 instances
# processed 6720 instances
# processed 6750 instances
# processed 6780 instances
# processed 6810 instances
# processed 6840 instances
# processed 6870 instances
# processed 6900 instances
# processed 6930 instances
# processed 6960 instances
# processed 6990 instances
# processed 7020 instances
# processed 7050 instances
# processed 7080 instances
# processed 7110 instances
# processed 7140 instances
# processed 7170 instances
# processed 7200 instances
# processed 7230 instances
# processed 7260 instances
# processed 7290 instances
# processed 7320 instances
# processed 7350 instances
# processed 7380 instances
# processed 7410 instances
# processed 7440 instances
# processed 7470 instances
# processed 7500 instances
# processed 7530 instances
# processed 7560 instances
# processed 7590 instances
# processed 7620 instances
# processed 7650 instances
# processed 7680 instances
# processed 7710 instances
# processed 7740 instances
# processed 7770 instances
# processed 7800 instances
# processed 7830 instances
# processed 7860 instances
# processed 7890 instances
# processed 7920 instances
# processed 7950 instances
# processed 7980 instances
# processed 8010 instances
# processed 8040 instances
# processed 8070 instances
# processed 8100 instances
# processed 8130 instances
# processed 8160 instances
# processed 8190 instances
# processed 8220 instances
# processed 8250 instances
# processed 8280 instances
# processed 8310 instances
# processed 8340 instances
# processed 8370 instances
# processed 8400 instances
# processed 8430 instances
# processed 8460 instances
# processed 8490 instances
# processed 8520 instances
# processed 8550 instances
# processed 8580 instances
# processed 8610 instances
# processed 8640 instances
# processed 8670 instances
# processed 8700 instances
# processed 8730 instances
# processed 8760 instances
# processed 8790 instances
# processed 8820 instances
# processed 8850 instances
# processed 8880 instances
# processed 8910 instances
# processed 8940 instances
# processed 8970 instances
# processed 9000 instances
# processed 9030 instances
# processed 9060 instances
# processed 9090 instances
# processed 9120 instances
# processed 9150 instances
# processed 9180 instances
# processed 9210 instances
# processed 9240 instances
# processed 9270 instances
# processed 9300 instances
# processed 9330 instances
# processed 9360 instances
# processed 9390 instances
# processed 9420 instances
# processed 9450 instances
# processed 9480 instances
# processed 9510 instances
# processed 9540 instances
# processed 9570 instances
# processed 9600 instances
# processed 9630 instances
# processed 9660 instances
# processed 9690 instances
# processed 9720 instances
# processed 9750 instances
# processed 9780 instances
# processed 9810 instances
# processed 9840 instances
# processed 9870 instances
# processed 9900 instances
# processed 9930 instances
# processed 9960 instances
# processed 9990 instances

# %%
index.add(X)

# %%
faiss.write_index(index, 'index')
